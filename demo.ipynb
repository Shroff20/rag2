# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"  # avoid windows memory leak in sklearn kmeans, set before Kmeans importimport parsers
import source.parsers as parsers
import source.database as database
import importlib
import os
import glob
importlib.reload(parsers)
importlib.reload(database)
import pandas as pd

# %%
device = "cuda"
database_folder = "./database_data"
os.environ["GOOGLE_API_KEY"] = "AIzaSyCp2r7wKvf_aNLc1gxzJTdhLrVAwaS-0WM"

VD = database.VectorDatabase(device, database_folder)
VD.info()
VD.clear_collections()
VD.create_collection()
# Out:
# collections: [Collection(name=documents)]
# Collection(name=documents) has 43 records
# deleted data in Collection(name=documents)
# `torch_dtype` is deprecated! Use `dtype` instead!
# created collection: Collection(name=documents) with 0 documents

# %%
glob_pattern = os.path.join('.', 'data', '*')
files = glob.glob(glob_pattern)

for file in files:
   VD.add_documents(file)
# Out:
# .\data\demo_textfile.txt
# - added 1 documents, 6 chunks
# .\data\HW 1 - Cave Flyer.pdf
# - added 1 documents, 3 chunks
# .\data\HW 2 - Complex Numbers.pdf
# - added 1 documents, 3 chunks
# .\data\HW 3 - Laplace Transforms and Intro to Controls and System ID.pdf
# - added 1 documents, 5 chunks
# .\data\HW 4 - Linearization and Dynamic Response.pdf
# - added 1 documents, 2 chunks
# .\data\HW 5 - Exam 1 in Matlab.pdf
# - added 1 documents, 3 chunks
# .\data\HW 6 - Routh Array and Root Locus.pdf
# - added 1 documents, 2 chunks
# .\data\HW 7 - Design Challenges.pdf
# - added 1 documents, 7 chunks
# .\data\HW 8 - Nyquist Stability.pdf
# - added 1 documents, 1 chunks
# .\data\HW 9 - Stability Margins and Compensation.pdf
# - added 1 documents, 1 chunks

# %%
VD.info()
# Out:
# collections: [Collection(name=documents)]
# Collection(name=documents) has 43 records

# %%
results = VD.collection.query(query_texts='test')
df_results = database._results_to_df(results, keep_cols = ['id', 'document'], document_length_limit= 10)
df_results
# Out:
#                                      id     document
# 0  6387ac27-fb24-5a6b-9830-4c22a1923477   We, theref
# 1  6387ac27-fb24-5a6b-9830-4c22a1923477   He has for
# 2  6387ac27-fb24-5a6b-9830-4c22a1923477   He has kep
# 3  6387ac27-fb24-5a6b-9830-4c22a1923477   In Congres
# 4  6387ac27-fb24-5a6b-9830-4c22a1923477   Carnegie M
# 5  6387ac27-fb24-5a6b-9830-4c22a1923477   timepoints
# 6  6387ac27-fb24-5a6b-9830-4c22a1923477  axis). \n7.
# 7  6387ac27-fb24-5a6b-9830-4c22a1923477   Carnegie M
# 8  6387ac27-fb24-5a6b-9830-4c22a1923477   In Congres
# 9  6387ac27-fb24-5a6b-9830-4c22a1923477   (https://d

# %%
query ="how do I install matlab"
df_results = VD.search(query, k = 10)
df_results
# Out:
# found 10 similar documents
#    distance                                    id                                           document                upload_date              creation_date  chunk_idx                                           fullpath                             source_id          modification_date                                          file_hash       source_type file_ext  N_chunks                                           basename         author pca tfidf                                              title                               page_lengths
# ...

# %%
query ="what options do I have to install matlab in detail"
response = VD.query(query, k = 10)
print(response.content)
# Out:
# found 10 similar documents
# You have three options to install and run MATLAB:
#
# 1.  **Download and install MATLAB locally:** You can download and install MATLAB on your own computer by following the instructions at https://www.cmu.edu/computing/software/all/matlab/.
# 2.  **Run MATLAB online through a browser:** You can access and use MATLAB through your web browser by visiting https://www.mathworks.com/products/matlab-online.html.
# 3.  **Run MATLAB through a Virtual Andrew session:** You can run MATLAB via a Virtual Andrew session. Instructions for this method can be found at https://www.cmu.edu/computing/services/endpoint/software/managed-desktops/how-to/virtual-andrew.html.
#
# (source: HW 1 - Cave Flyer.pdf)

# %%
import pandas as pd
import ast




def results_to_df(results, document_length_limit = None):

    d = {}
    if 'distances' in results.keys():
        d['distance'] = results['distances']
    if 'ids' in results.keys():
        d['id'] = results['ids']
    if 'documents' in results.keys():  
        d['document'] = results['documents']
    if 'embeddings' in results.keys():
        d['embedding'] = [row for row in results['embeddings']]
    df = pd.DataFrame.from_dict(d)

    if 'metadatas' in results.keys():
        df_metadata = pd.DataFrame(results['metadatas'], index = range(len(df))).drop(columns = 'id')
        df = pd.concat([df, df_metadata], axis = 1).reset_index(drop = True)

    datetime_format =  r"%Y-%m-%d %H:%M:%S.%f"
    type_converter = {}
    type_converter['creation_date'] = lambda x:  pd.to_datetime(x, format = datetime_format)
    type_converter['upload_date'] = lambda x:  pd.to_datetime(x, format = datetime_format)
    type_converter['modification_date'] = lambda x:  pd.to_datetime(x, format = datetime_format)
    type_converter['page_lengths'] = lambda x:  x.apply(ast.literal_eval)
    type_converter['document'] = lambda x:  x.str[:document_length_limit]

    for col in df.columns:
        if col in type_converter.keys():
            df[col] = type_converter[col](df[col])

    return df


results = VD.collection.get(
        limit=10,
        offset=0,
        include=['documents', 'metadatas', 'embeddings'] # Specify what to include
    )


df = results_to_df(results, document_length_limit= 6)

df
# Out:
#                                      id document                                          embedding                      fullpath                upload_date         author                  title               basename pca       source_type          modification_date      page_lengths                                          file_hash  chunk_idx tfidf              creation_date                             source_id file_ext  N_chunks
# 0  c480bfc2-e3ea-5aa5-bbf5-7ce14b5c173a   In Con  [-0.07415771484375, 0.04840087890625, -0.00752...      .\data\demo_textfile.txt 2025-11-30 20:20:22.739203                     demo_textfile.txt      demo_textfile.txt  ()     full document 2025-11-29 23:40:34.881779           (8149,)  85ed45c9a6c1555ac04855ce9f4aad1432f0f6888b3721...         -1    () 2025-11-29 23:39:54.799670  c480bfc2-e3ea-5aa5-bbf5-7ce14b5c173a     .txt         0
# ...

# %%
# labels, inertia, df_pca = DS.run_kmeans(n_clusters = 3)
# df_pca

# %%
# id = DS.collection.get(limit = 1)['ids'][0]
# df = DS.search_by_id(id, k =10, where = {'source_type':'full document'})
# print(df)

# %%
# import pandas as pd

# id = DS.collection.get(limit = 1)['ids'][0]
# r = DS.collection.get(id, include = ['embeddings'])
# embedding = r['embeddings']
# results = DS.collection.query(query_embeddings=embedding, include=['distances', 'metadatas', 'documents'])
# df_results= shroff_rag._results_to_df(results)[0]
# df_results = df_results.sort_values('distance')
# df_results
