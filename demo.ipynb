# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"  # avoid windows memory leak in sklearn kmeans, set before Kmeans importimport parsers
import source.parsers as parsers
import source.database as database
import importlib
import os
import glob
importlib.reload(parsers)
importlib.reload(database)
import pandas as pd

# %%
device = "cuda"
database_folder = "D:\\tmp\\database_data"
os.environ["GOOGLE_API_KEY"] = "AIzaSyCp2r7wKvf_aNLc1gxzJTdhLrVAwaS-0WM"

VD = database.VectorDatabase(device, database_folder)
VD.info()
VD.clear_collections()
VD.create_collection()
# Out:
# collections: []
# `torch_dtype` is deprecated! Use `dtype` instead!
# created collection: Collection(name=documents) with 0 documents

# %%
glob_pattern = os.path.join('.', 'data', '*')
files = glob.glob(glob_pattern)


VD.add_documents(files)
# Out:
# parsing [.\data\demo_textfile.txt]
# parsing [.\data\HW 1 - Cave Flyer.pdf]
# parsing [.\data\HW 2 - Complex Numbers.pdf]
# parsing [.\data\HW 3 - Laplace Transforms and Intro to Controls and System ID.pdf]
# parsing [.\data\HW 4 - Linearization and Dynamic Response.pdf]
# parsing [.\data\HW 5 - Exam 1 in Matlab.pdf]
# parsing [.\data\HW 6 - Routh Array and Root Locus.pdf]
# parsing [.\data\HW 7 - Design Challenges.pdf]
# parsing [.\data\HW 8 - Nyquist Stability.pdf]
# parsing [.\data\HW 9 - Stability Margins and Compensation.pdf]
# - added 10 documents, 33 chunks

# %%
VD.info()
# Out:
# collections: [Collection(name=documents)]
# Collection(name=documents) has 43 records

# %%
VD.get(include = ['documents', 'embeddings'])
# Out:
#                                       id                                           document                                          embedding
# 0   b620ba0a-f2d0-5893-8fb0-f5611726f076  In Congress, July 4, 1776\n\nThe unanimous Dec...  [-0.074165866, 0.04833681, -0.007595299, 0.006...
# 1   d00a351a-96b3-560b-8b31-f7dab9abc247  In Congress, July 4, 1776\n\nThe unanimous Dec...  [-0.023325738, 0.020089287, 0.014753894, -0.00...
# 2   ac16fb33-1007-5f21-badf-51326739eae1  We hold these truths to be self-evident, that ...  [-0.082173355, 0.092735216, -0.04089193, -0.00...
# 3   6e75dfa6-61ce-5d73-9f0b-97e593b36e70  He has forbidden his Governors to pass Laws of...  [0.00507496, 0.018376272, 0.05454693, -0.00800...
# 4   7f7ee21b-13c6-5bd6-927b-45ae4a2d217a  He has kept among us, in times of peace, Stand...  [-0.023129975, 0.050913908, 0.018541133, -0.09...
# ...

# %%
results = VD.collection.query(query_texts='test', include = ['embeddings'])
df_results = database._results_to_df(results, keep_cols = ['id', 'document', 'embedding'], document_length_limit= 10)
df_results
# Out:
#                                      id                                          embedding
# 0  6387ac27-fb24-5a6b-9830-4c22a1923477  [-0.05762239, -0.027064256, 0.0042288327, -0.0...
# 1  6e75dfa6-61ce-5d73-9f0b-97e593b36e70  [0.00507496, 0.018376272, 0.05454693, -0.00800...
# 2  7f7ee21b-13c6-5bd6-927b-45ae4a2d217a  [-0.023129975, 0.050913908, 0.018541133, -0.09...
# 3  d00a351a-96b3-560b-8b31-f7dab9abc247  [-0.023325738, 0.020089287, 0.014753894, -0.00...
# 4  fd404feb-816b-5840-b735-a1266097fa05  [-0.07055521, -0.02415476, -0.015510819, 0.000...
# 5  a15a1017-2f3c-53dd-b46b-b1e946be0626  [-0.07547417, -0.059211493, -0.07448536, -0.04...
# 6  31d1eafa-c729-54c6-ac3d-5255371c96e7  [-0.10168259, -0.034086574, -0.030255536, 0.01...
# 7  a6a533b9-7542-5de9-997e-a8bf62a2567d  [0.06839771, 0.051735345, -0.07544185, -0.0258...
# 8  b620ba0a-f2d0-5893-8fb0-f5611726f076  [-0.074165866, 0.04833681, -0.007595299, 0.006...
# ...

# %%
r = VD.collection.get(limit = 2)

database._results_to_df(r)
# Out:
#                                      id                                           document       source_type                                          file_hash  chunk_idx              title  N_chunks   modification_date author page_lengths           basename       creation_date                  fullpath file_ext                             source_id         upload_date
# 0  b620ba0a-f2d0-5893-8fb0-f5611726f076  In Congress, July 4, 1776\n\nThe unanimous Dec...     full document  85ed45c9a6c1555ac04855ce9f4aad1432f0f6888b3721...         -1  demo_textfile.txt         0 2025-11-29 23:40:34            [8148.0]  demo_textfile.txt 2025-11-29 23:39:54  .\data\demo_textfile.txt     .txt  b620ba0a-f2d0-5893-8fb0-f5611726f076 2025-12-04 13:01:16
# ...

# %%
r = VD.collection.query(query_texts=['hello'], n_results=2)
print(VD.collection.count())
print(r)
# Out:
# 43
# ...

# %%
query ="hello"
df_results = VD.search(query, k = 2)
df_results
# Out:
# {'ids': [['2443d291-d7bc-5b92-a554-04af388319a1', '6e75dfa6-61ce-5d73-9f0b-97e593b36e70']], 'embeddings': None, 'documents': [['He has constrained our fellow Citizens taken Captive on the high Seas to bear Arms against their Country, to become the executioners of their friends and Brethren, or to fall themselves by their Hands.\n\nHe has excited domestic insurrections amongst us, and has endeavoured to bring on the inhabitants of our frontiers, the merciless Indian Savages, whose known rule of warfare, is an undistinguished destruction of all ages, sexes and conditions.\n\nIn every stage of these Oppressions We have Petitioned for Redress in the most humble terms: Our repeated Petitions have been answered only by repeated injury. A Prince, whose character is thus marked by every act which may define a Tyrant, is unfit to be the ruler of a free people.\n\nNor have We been wanting in attentions to our Brittish brethren. We have warned them from time to time of attempts by their legisla
# ...

# %%
query ="how do I install matlab"
df_results = VD.search(query, k = 2)
df_results
# Out:
# {'ids': [['84d1843d-1bd1-53b8-ae55-2c2c939cdb37', '278661f7-8e8d-5a6b-b0e9-3a795d3c1d75']], 'embeddings': None, 'documents': [['Carnegie Mellon University 24-451: Feedback Control Systems \n Instructor: Dr. Sameer Shroff \n 1 \nHomework 1: Cave Flyer \n \n \n \nInstructions: \n1) Run MATLAB using one of these methods: \na) Download and install MATLAB locally \n(https://www.cmu.edu/computing/software/all/matlab/). \nb) Run MATLAB online through a browser (https://www.mathworks.com/products/matlab-\nonline.html). \nc) Run MATLAB through a Virtual Andrew session \n(https://www.cmu.edu/computing/services/endpoint/software/managed-\ndesktops/how-to/virtual-andrew.html). \n2) Download the file CaveFly.zip from the course files on Canvas, and unzip \n3) Open MATLAB and navigate to the file.  Add the folder containing the file to the MATLAB \npath (On the toolbar, select Environment | Set Path). \n4) Open the latest version of CaveFly.m. \na) Set the value of M.controller_dir to point to the
# ...

# %%
query ="what options do I have to install matlab in detail"
response = VD.query(query, k = 10)
print(response.content)
# Out:
# {'ids': [['84d1843d-1bd1-53b8-ae55-2c2c939cdb37', '278661f7-8e8d-5a6b-b0e9-3a795d3c1d75', '34d76a86-10c7-52c4-b9fa-a71985820b17', '7fc073a6-6e1e-56c1-8e0e-9cadc79ce416', '66d92bf3-2b6b-5b92-b5a8-d52d9a70f6ce', 'c6aeca0f-6ea7-585e-b995-1cf9b71baef3', '31d1eafa-c729-54c6-ac3d-5255371c96e7', '6da8d02a-6ffa-5410-8915-cb4992b2a3e0', 'ad157204-5bfd-5c8f-b7e0-8e1091b814ab', 'a9b7e972-fbf0-5ff5-af3c-19fba77410f6']], 'embeddings': None, 'documents': [['Carnegie Mellon University 24-451: Feedback Control Systems \n Instructor: Dr. Sameer Shroff \n 1 \nHomework 1: Cave Flyer \n \n \n \nInstructions: \n1) Run MATLAB using one of these methods: \na) Download and install MATLAB locally \n(https://www.cmu.edu/computing/software/all/matlab/). \nb) Run MATLAB online through a browser (https://www.mathworks.com/products/matlab-\nonline.html). \nc) Run MATLAB through a Virtual Andrew session \n(https://www.cmu.edu/computing/services/endpoint/software/managed-\ndesktops/how-to/virtual-andrew.html). \n2)
# ...

# %%
import source.cluster as cluster_analysis
importlib.reload(cluster_analysis)

CA = cluster_analysis.ClusterAnalyis(VD)


CA.calculate_pca()
CA.perform_kmeans_clustering(n_clusters=5)


df = VD.get(keep_cols = ['id', 'kmeans_cluster_idx', 'pca_embedding'])
# Out:
# embeddings matrix is (43, 384)
# pca matrix is (43, 43)
# updated metadata for 43 records for the following keys: {'pca_embedding'}
# embeddings matrix is (43, 43)
# performed kmeans clustering with 5 clusters
# kmeans_cluster_idx
# 4     7
# 3     7
# 2     3
# 1    24
# 0     2
# Name: count, dtype: int64
# updated metadata for 43 records for the following keys: {'kmeans_cluster_idx'}

# %%
df = VD.get(keep_cols = ['id', 'kmeans_cluster_idx', 'pca_embedding'])
df
# Out:
#                                       id  kmeans_cluster_idx                                      pca_embedding
# 0   b620ba0a-f2d0-5893-8fb0-f5611726f076                   4  [-0.962, -0.08295, 0.0772, 0.07245, 0.06036, 0...
# 1   d00a351a-96b3-560b-8b31-f7dab9abc247                   4  [-0.892, -0.0319, 0.003881, 0.09717, 0.09216, ...
# 2   ac16fb33-1007-5f21-badf-51326739eae1                   4  [-0.8535, -0.02974, 0.0956, 0.03983, -0.0127, ...
# 3   6e75dfa6-61ce-5d73-9f0b-97e593b36e70                   4  [-0.773, -0.07635, 0.1388, -0.1243, -0.0474, -...
# 4   7f7ee21b-13c6-5bd6-927b-45ae4a2d217a                   4  [-0.828, -0.04965, -0.06226, -0.08014, -0.0589...
# 5   2443d291-d7bc-5b92-a554-04af388319a1                   4  [-0.8, -0.02301, 0.11774, -0.11304, -0.04816, ...
# 6   6387ac27-fb24-5a6b-9830-4c22a1923477                   4  [-0.9175, -0.0663, 0.0829, 0.0478, -0.01009, 0...
# ...

# %%
id = parsers.generate_document_uuid_from_path(files[0])
r = VD.collection.get(ids = id, include = [])
id_exists = len(r['ids'])>0

print(id_exists)
# Out:
# True

# %%
df = VD.get(keep_cols=['pca_embedding'])
df
# Out:
#                                         pca_embedding
# 0   [-0.962, -0.08295, 0.0772, 0.07245, 0.06036, 0...
# 1   [-0.892, -0.0319, 0.003881, 0.09717, 0.09216, ...
# 2   [-0.8535, -0.02974, 0.0956, 0.03983, -0.0127, ...
# 3   [-0.773, -0.07635, 0.1388, -0.1243, -0.0474, -...
# 4   [-0.828, -0.04965, -0.06226, -0.08014, -0.0589...
# 5   [-0.8, -0.02301, 0.11774, -0.11304, -0.04816, ...
# 6   [-0.9175, -0.0663, 0.0829, 0.0478, -0.01009, 0...
# 7   [0.1947, -0.05695, -0.4592, -0.014175, 0.02351...
# 8   [0.1943, -0.04697, -0.465, -0.022, 0.03333, -0...
# 9   [0.02481, 0.1566, -0.502, -0.1741, 0.09106, -0...
# 10  [-0.0343, 0.2434, -0.4521, -0.1904, 0.2339, 0....
# 11  [0.1531, 0.11163, 0.00729, 0.4543, -0.3098, -0...
# 12  [0.1531, 0.11163, 0.00729, 0.4543, -0.3098, -0...
# 13  [0.07367, 0.293, -0.0403, 0.5645, -0.15, -0.04...
# 14  [0.01563, 0.4333, 0.02293, 0.3228, 0.1525, 0.1...
# 15  [0.06433, -0.549, -0.3894, 0.1384, -0.1084, -0...
# ...
