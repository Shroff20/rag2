# %%
import source.parsers as p
import importlib
importlib.reload(p)
from pprint import pprint

# %%
fn = r'..\\data\\HW 1 - Cave Flyer.pdf'

D=p.parse_document(fn)

pprint(D)
# Out:
# ..\\data\\HW 1 - Cave Flyer.pdf
# [ParserOuput(fullpath='..\\\\data\\\\HW 1 - Cave Flyer.pdf',
#              document='Carnegie Mellon University 24-451: Feedback Control '
#                       'Systems \n'
#                       ' Instructor: Dr. Sameer Shroff \n'
#                       ' 1 \n'
#                       'Homework 1: Cave Flyer \n'
#                       ' \n'
#                       ' \n'
#                       ' \n'
#                       'Instructions: \n'
#                       '1) Run MATLAB using one of these methods: \n'
#                       'a) Download and install MATLAB locally \n'
#                       '(https://www.cmu.edu/computing/software/all/matlab/). \n'
#                       'b) Run MATLAB online through a browser '
#                       '(https://www.mathworks.com/products/matlab-\n'
#                       'online.html). \n'
#                       'c) Run MATLAB through a Virtual Andrew session \n'
# ...

# %%
D[1].convert_to_vector_database_format()
# Out:
# ('84d1843d-1bd1-53b8-ae55-2c2c939cdb37',
# ...
