# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"  # avoid windows memory leak in sklearn kmeans, set before Kmeans importimport parsers
import shroff_rag
import importlib
import os
import glob
import parsers

importlib.reload(shroff_rag)
importlib.reload(parsers)
# Out:
# <module 'parsers' from "c:\\Users\\ssmee\\Google Drive\\Sameer's Files\\Jobs\\Dynamics_and_machine_learning\\rag2\\parsers.py">

# %%
device = "cuda"
database_folder = "./database_data"
os.environ["GOOGLE_API_KEY"] = "AIzaSyCp2r7wKvf_aNLc1gxzJTdhLrVAwaS-0WM"

DS = shroff_rag.DataStore(device, database_folder)
DS.info()
DS.clear_collections()
DS.create_collection()
# Out:
# collections: [Collection(name=documents)]
# deleted data in Collection(name=documents)
# created collection: Collection(name=documents) with 0 documents

# %%
glob_pattern = os.path.join('.', 'data', '*.pdf')
files = glob.glob(glob_pattern)

for file in files:
   DS.add_document(file)
# Out:
# - added .\data\HW 1 - Cave Flyer.pdf
#    - added 5 chunks from .\data\HW 1 - Cave Flyer.pdf
# - added .\data\HW 2 - Complex Numbers.pdf
#    - added 6 chunks from .\data\HW 2 - Complex Numbers.pdf
# - added .\data\HW 3 - Laplace Transforms and Intro to Controls and System ID.pdf
#    - added 8 chunks from .\data\HW 3 - Laplace Transforms and Intro to Controls and System ID.pdf
# - added .\data\HW 4 - Linearization and Dynamic Response.pdf
#    - added 3 chunks from .\data\HW 4 - Linearization and Dynamic Response.pdf
# - added .\data\HW 5 - Exam 1 in Matlab.pdf
#    - added 7 chunks from .\data\HW 5 - Exam 1 in Matlab.pdf
# - added .\data\HW 6 - Routh Array and Root Locus.pdf
#    - added 4 chunks from .\data\HW 6 - Routh Array and Root Locus.pdf
# - added .\data\HW 7 - Design Challenges.pdf
#    - added 13 chunks from .\data\HW 7 - Design Challenges.pdf
# - added .\data\HW 8 - Nyquist Stability.pdf
#    - added 2 chunks from .\data\HW 8 - Nyquist Stability.pdf
# - added .\data\HW 9 - Stability Margins and Compensation.pdf
#    - added 2 chunks from .\data\HW 9 - Stability Margins and Compensation.pdf

# %%
DS.info()
# Out:
# collections: [Collection(name=documents)]

# %%
query ="how do I install matlab"
df_results = DS.search(query, k = 10)
df_results
# Out:
# found 10 similar documents
#    distance                                           basename                                    id  N_chunks                             source_id                               page_lengths       source_type         author file_ext pca                 upload_date                                           fullpath           modification_date                                               hash               creation_date  chunk_idx                                           document
# 0  0.467617                              HW 1 - Cave Flyer.pdf  ee3022e9-93f0-410c-87bb-695cb4a1f7dd         5  7353459a-33c2-544c-81f2-4e8877cddfcc                           [974, 2735, 291]  chunked document  Sameer Shroff     .pdf      2025-11-28 17:59
  chunked document  Sameer Shroff     .pdf      2025-11-28 17:59:26.771735                .\data\HW 7 - Design Challenges.pdf  2022-10-23 12:31:27.302366  abec6a608c256b197114106e8843696d0ea0cf2fff8710...  2025-11-26 11:27:12.514347          7  Carnegie Mellon University 24-451: Feedback Co...
# 7  0.726754                       HW 7 - Design Challenges.pdf  64c62120-1b9c-4f98-813f-11cca0e95b1e        13  8a5a4e88-6b39-5898-8682-6953f1a90da7  [1352, 1462, 1842, 401, 1634, 1157, 1138]  chunked document  Sameer Shroff     .pdf      2025-11-28 17:59:26.771735                .\data\HW 7 - Design Challenges.pdf  2022-10-23 12:31:27.302366  abec6a608c256b197114106e8843696d0ea0cf2fff8710...  2025-11-26 11:27:12.514347          0  Carnegie Mellon University 24-451: Feedback Co...
# 8  0.727744  HW 3 - Laplace Transforms and Intro to Control...  bdaf86d0-32ad-4350-8923-c3710d230480         8  92843a15-ddf5-51b5-b851-ed3b159a4e25                    [2363, 1621, 1323, 682]  chunked document  Sameer Shroff     .pdf      2025-11-28 17:59:25.693430  .\data\HW 3 - Laplace Transforms and Intro to ...  2022-09-07 20:37:59.854000  b907d592332785225f53963d7e64d3379ba273adfb78ba...  2025-11-26 11:27:12.509331          2  inputs and outputs of the function, listed bel...
# 9  0.738187                         HW 2 - Complex Numbers.pdf  77591773-ed8e-4dc7-b517-9a0b2e75daf7         6  3dc8bb69-454a-535c-9815-02ae4e274a4f                          [1937, 1550, 600]  chunked document  Sameer Shroff     .pdf      2025-11-28 17:59:25.449264                  .\data\HW 2 - Complex Numbers.pdf  2024-08-27 20:24:40.731488  2c913fd6cc22e915214e21fca277d2db112d01b118af2b...  2025-11-26 11:27:12.508334          4  𝑐1 + 𝑐2𝑗 by 𝜃 degrees.  Describe your methodol...

# %%
query ="what options do I have to install matlab in detail"
response = DS.query(query, k = 10)
print(response.content)
# Out:
# found 10 similar documents
# You have three options to install or run MATLAB:
#
# 1.  **Download and install MATLAB locally:** You can download and install MATLAB on your computer from the following link: https://www.cmu.edu/computing/software/all/matlab/.
# 2.  **Run MATLAB online through a browser:** You can access and use MATLAB online through your web browser at: https://www.mathworks.com/products/matlab-online.html.
# 3.  **Run MATLAB through a Virtual Andrew session:** You can run MATLAB via a Virtual Andrew session by following the instructions at: https://www.cmu.edu/computing/services/endpoint/software/managed-desktops/how-to/virtual-andrew.html.
#
# (source: HW 1 - Cave Flyer.pdf)

# %%
DS.compute_pca()
# Out:
# embeddings matrix is (59, 384)
# pca matrix is (59, 59)
# saved pca data to vector database

# %%
labels, inertia, pca_matrix = DS.run_kmeans(n_clusters = 3)
# Out:
# c:\Users\ssmee\.conda\envs\rag2\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d',  proj_type='ortho')
ax.scatter(pca_matrix[:,0], pca_matrix[:,1], depthshade=False, c = labels)
ax.set_xlabel('pca component 1')
ax.set_ylabel('pca component 2')
#ax.set_zlabel('pca component 3')
#ax.view_init(elev=90, azim=-90) 
ax.tick_params(axis='z', left=False, labelleft=False) # Hide y-axis ticks and labels
