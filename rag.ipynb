# %%
import shroff_rag
import importlib
import os
import glob
import parsers

importlib.reload(shroff_rag)
importlib.reload(parsers)
# Out:
# <module 'parsers' from "c:\\Users\\ssmee\\Google Drive\\Sameer's Files\\Jobs\\Dynamics_and_machine_learning\\rag2\\parsers.py">

# %%
device = "cuda"
database_folder = "./database_data"
os.environ["GOOGLE_API_KEY"] = "AIzaSyCp2r7wKvf_aNLc1gxzJTdhLrVAwaS-0WM"

DS = shroff_rag.DataStore(device, database_folder)
DS.clear_collections()
DS.create_collection()
# Out:
# deleted Collection(name=documents)
# created collection: Collection(name=documents)

# %%
glob_pattern = os.path.join('.', 'data', '*.pdf')
files = glob.glob(glob_pattern)

for file in files:
   DS.add_document(file)
# Out:
# - added .\data\HW 1 - Cave Flyer.pdf
#    - added 5 chunks from .\data\HW 1 - Cave Flyer.pdf
# - added .\data\HW 2 - Complex Numbers.pdf
#    - added 6 chunks from .\data\HW 2 - Complex Numbers.pdf
# - added .\data\HW 3 - Laplace Transforms and Intro to Controls and System ID.pdf
#    - added 8 chunks from .\data\HW 3 - Laplace Transforms and Intro to Controls and System ID.pdf
# - added .\data\HW 4 - Linearization and Dynamic Response.pdf
#    - added 3 chunks from .\data\HW 4 - Linearization and Dynamic Response.pdf
# - added .\data\HW 5 - Exam 1 in Matlab.pdf
#    - added 7 chunks from .\data\HW 5 - Exam 1 in Matlab.pdf
# - added .\data\HW 6 - Routh Array and Root Locus.pdf
#    - added 4 chunks from .\data\HW 6 - Routh Array and Root Locus.pdf
# - added .\data\HW 7 - Design Challenges.pdf
#    - added 13 chunks from .\data\HW 7 - Design Challenges.pdf
# - added .\data\HW 8 - Nyquist Stability.pdf
#    - added 2 chunks from .\data\HW 8 - Nyquist Stability.pdf
# - added .\data\HW 9 - Stability Margins and Compensation.pdf
#    - added 2 chunks from .\data\HW 9 - Stability Margins and Compensation.pdf

# %%
DS.info()
# Out:
# collections: [Collection(name=documents)]

# %%
query ="how do I install matlab"
df_results = DS.search(query, k = 3)
df_results
# Out:
#    distance                     basename                                    id         author                            fullpath file_ext       source_type               creation_date        page_lengths  chunk_idx                             source_id                                               hash pca           modification_date  N_chunks                 upload_date                                           document
# 0  0.467617        HW 1 - Cave Flyer.pdf  192f3934-845d-4596-bbef-1d43ef1edcd0  Sameer Shroff        .\data\HW 1 - Cave Flyer.pdf     .pdf  chunked document  2025-11-26 11:27:12.507327    [974, 2735, 291]          0  7353459a-33c2-544c-81f2-4e8877cddfcc  d235a1898843e3a439eabc58b387565f659900d5644604...      2024-08-25 16:26:44.119668         5  2025-11-26 15:31:26.841094  Carnegie Mellon University 24-451: Feedback Co...
# 1  0.477226        HW 1 - Cave Flyer.pdf  7353459a-33c2-544c-81f2-4e8877cddfcc  Sameer Shroff        .\data\HW 1 - Cave Flyer.pdf     .pdf     full document  2025-11-26 11:27:12.507327    [974, 2735, 291]         -1  7353459a-33c2-544c-81f2-4e8877cddfcc  d235a1898843e3a439eabc58b387565f659900d5644604...      2024-08-25 16:26:44.119668         0  2025-11-26 15:31:26.841094  Carnegie Mellon University 24-451: Feedback Co...
# 2  0.660489  HW 5 - Exam 1 in Matlab.pdf  c141bf08-1567-403e-83eb-8beb0d40da64  Sameer Shroff  .\data\HW 5 - Exam 1 in Matlab.pdf     .pdf  chunked document  2025-11-26 11:27:12.511332  [1749, 2024, 1216]          3  aca9ef5a-8288-54e0-8231-4268d682efd2  910573961d42ea022be07ca314325b4400a963f89e1795...      2024-09-25 17:53:25.497000         7  2025-11-26 15:31:27.791480  j. What happens as K increases?  Show and exam...

# %%
query ="what options do I have to install matlab"
response = DS.query(query, k = 20)
print(response.content)
# Out:
# You have three options to install or run MATLAB:
# 1. Download and install MATLAB locally.
# 2. Run MATLAB online through a browser.
# 3. Run MATLAB through a Virtual Andrew session.
# (source: HW 1 - Cave Flyer.pdf)
